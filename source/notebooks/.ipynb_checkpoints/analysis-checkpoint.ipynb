# %%
# !pip install psycopg2-binary
# Out:
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.11-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (4.9 kB)
# Downloading psycopg2_binary-2.9.11-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 444.7 kB/s eta 0:00:0000:0100:01
# Installing collected packages: psycopg2-binary
# Successfully installed psycopg2-binary-2.9.11

# %%
import scipy as sp
import psycopg2
import pandas as pd
from matplotlib import pyplot as plt

# %%
try:
    connection = psycopg2.connect(
        host="postgres",
        database="taxi_db",
        user="root",
        password="qwerty",
        port=5432
    )
    print("Успешно подключено к базе данных", flush=True)
    query = "SELECT * FROM taxi_rides"
    rides_df = pd.read_sql(query, connection)
    #print(rides_df)
except Exception as e:
    print(f"Error: {e}")
# Out:
# Успешно подключено к базе данных
# /tmp/ipykernel_203/2619526532.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   rides_df = pd.read_sql(query, connection)

# %%
print("Распределение поездок по способу оплаты:")
rides_df["payment_method"].value_counts()
# Out:
# Распределение поездок по способу оплаты:
# payment_method
# cash    132
# card    129
# Name: count, dtype: int64

# %%
print("Основная статистика по поездкам:")
print(rides_df[["distance_km", "price", "duration_min", "rating"]].describe())
# Out:
# Основная статистика по поездкам:
#        distance_km        price  duration_min      rating
# count   261.000000   261.000000    261.000000  261.000000
# mean     26.075977   931.894789     63.927203    3.034100
# std      14.633263   536.246965     33.286727    1.219436
# min       1.050000   123.750000      5.000000    1.000000
# 25%      12.400000   531.610000     34.000000    2.000000
# 50%      26.200000   857.040000     67.000000    3.000000
# 75%      39.740000  1224.390000     92.000000    4.100000
# max      49.760000  2879.050000    120.000000    5.000000

# %%
average_price = rides_df.groupby("vehicle_type")["price"].mean().sort_values(ascending=False)
print("Средняя цена по типам автомобилей:")
print(average_price)
# Out:
# Средняя цена по типам автомобилей:
# vehicle_type
# business    1499.847647
# comfort     1040.558769
# economy      769.095062
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10,6))
rides_df["vehicle_type"].value_counts().plot(kind="bar")
plt.title("Распределение поездок по типам автомобилей")
plt.xlabel("Тип автомобиля")
plt.ylabel("Количество поездок")
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.scatter(rides_df["distance_km"], rides_df["price"])
plt.title("Зависимость цены от расстояния")
plt.xlabel("Расстояние (км)")
plt.ylabel("Цена (руб)")
plt.show()
print("Так как данные генерировались слу")
# Out:
# Так как данные генерировались слу

# %%
plt.figure(figsize=(10, 6))
rides_df['rating'].hist(bins=20)
plt.title('Распределение рейтингов поездок')
plt.xlabel('Рейтинг')
plt.ylabel('Количество')
plt.show()
